# %%
import pandas as pd

# %%
df = pd.read_csv("sample_details.csv")

# %%
df.head()
# Out:
#   protein chain  group  group1             group1.1 protein.1  #amino_acids  \
# 0    3P45     A  CASP6  CASP6E  Executioner_caspase      3P45           133
# 1    3QNW     A  CASP6  CASP6E  Executioner_caspase      3QNW           134
# 2    2QLF     A  CASP7  CASP7E  Executioner_caspase      2QLF           139
# 3    3EDR     A  CASP7  CASP7E  Executioner_caspase      3EDR           139
# 4    4ZVO     A  CASP7  CASP7E  Executioner_caspase      4ZVO           139
#
#    percent_threshold  percent_threshold1  percent_threshold1.1  \
# 0                100                  90                    80
# 1                100                  90                    80
# 2                100                  90                    80
# 3                100                  90                    80
# 4                100                  90                    80
#
#    percent_threshold1.2
# 0                    70
# 1                    70
# 2                    70
# 3                    70
# ...

# %%
chain_dict = dict([(p,c) for p,c in zip(df.protein, df.chain)])

# %%
files = df['protein'].tolist()

# %%
files
# Out:
# ['3P45',
#  '3QNW',
#  '2QLF',
#  '3EDR',
#  '4ZVO',
#  '4ZVP',
#  '4ZVQ',
#  '1PAU',
#  '1RE1',
#  '1RHJ',
#  '1RHK',
#  '1RHQ',
#  '1RHR',
#  '1RHU',
#  '2QL5',
#  '2QL7',
#  '2QL9',
#  '2QLB',
#  '2QLJ',
#  '2XZD',
#  '3IBC',
#  '3IBF',
#  '3P4U',
#  '1NME',
#  '2CJX',
#  '2CJY',
#  '2CNO',
#  '2DKO',
#  '2FQQ',
#  '2Y1L',
#  '1QTN',
#  '3KJN',
#  '3KJQ',
#  '6X8H',
#  '3R5J',
#  '3R7N',
#  '3R6L',
#  '3R7B',
#  '3R6G',
#  '1PYO',
#  '3R7S',
#  '3RJM',
#  '2P2C',
#  '3NS7',
#  '2H4Y',
#  '2HBZ',
#  '3D6H',
#  '5MMV',
#  '5MTK',
#  '2H51',
#  '6KN0',
#  '2H4W',
#  '2HBQ',
#  '2HBR',
#  '2H54',
#  '2HBY',
#  '4FEA',
#  '6BZ9',
#  '3D6F',
#  '3D6M',
#  '6KMZ',
#  '6PZP',
#  '6F6R',
#  '5H33',
#  '5L08',
#  '5H31',
#  '4ZBW',
#  '7LVM',
#  '1SHL',
#  '3V6M',
#  '1SHJ',
#  '6PX9',
#  '4HQ0',
#  '3H11',
#  '3K7E',
#  '4HQR',
#  '3S8E',
#  '4FXO',
#  '6GKF',
#  '2WDP',
#  '6DEV',
#  '6DEU',
#  '6S9K',
#  '2K7Z',
#  '6Y8B',
#  '2AR9',
#  '4JJ8',
#  '1K86',
#  '1QX3',
#  '3H1P',
# ...
